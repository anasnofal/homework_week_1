# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
data=pd.read_csv('yellow_tripdata_2019-01.csv',nrows=1000)
data
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1           1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2           2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3           2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4           2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ..        ...                  ...                   ...              ...
# 995         2  2018-12-31 23:56:51   2019-01-01 00:07:25                4
# 996         2  2019-01-01 00:12:12   2019-01-01 00:16:58                4
# 997         2  2019-01-01 00:22:03   2019-01-01 00:34:30                5
# 998         2  2019-01-01 00:35:42   2019-01-01 00:56:04                5
# 999         2  2019-01-01 00:43:59   2019-01-01 00:49:31                1
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
data['tpep_pickup_datetime']=pd.to_datetime(data['tpep_pickup_datetime'])
data['tpep_dropoff_datetime']=pd.to_datetime(data['tpep_dropoff_datetime'])

# %%
data[['tpep_pickup_datetime','tpep_dropoff_datetime']]
# Out:
#     tpep_pickup_datetime tpep_dropoff_datetime
# 0    2019-01-01 00:46:40   2019-01-01 00:53:20
# 1    2019-01-01 00:59:47   2019-01-01 01:18:59
# 2    2018-12-21 13:48:30   2018-12-21 13:52:40
# 3    2018-11-28 15:52:25   2018-11-28 15:55:45
# 4    2018-11-28 15:56:57   2018-11-28 15:58:33
# ..                   ...                   ...
# 995  2018-12-31 23:56:51   2019-01-01 00:07:25
# 996  2019-01-01 00:12:12   2019-01-01 00:16:58
# 997  2019-01-01 00:22:03   2019-01-01 00:34:30
# 998  2019-01-01 00:35:42   2019-01-01 00:56:04
# 999  2019-01-01 00:43:59   2019-01-01 00:49:31
#
# [1000 rows x 2 columns]

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
engine.connect()

# %%
print(pd.io.sql.get_schema(data,name='yellow_taxi_data',con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
data_iter= pd.read_csv('yellow_tripdata_2019-01.csv',iterator=True,chunksize=10000)
data_iter

# %%
df=next(data_iter)
df
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0            1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1            1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2            2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3            2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4            2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ...        ...                  ...                   ...              ...
# 9995         2  2019-01-01 00:20:18   2019-01-01 00:24:40                2
# 9996         2  2019-01-01 00:25:29   2019-01-01 00:45:00                2
# 9997         2  2019-01-01 00:47:19   2019-01-01 00:55:38                2
# 9998         2  2019-01-01 00:31:41   2019-01-01 00:56:26                1
# 9999         2  2019-01-01 00:58:04   2019-01-01 01:15:24                1
#
#       trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# ...

# %%
df['tpep_pickup_datetime']=pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime']=pd.to_datetime(df['tpep_dropoff_datetime'])
df.head(0).to_sql(name='yellow_taxi_data',con=engine,if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con = engine, if_exists='append')
# Out:
# CPU times: user 338 ms, sys: 9.09 ms, total: 347 ms
# Wall time: 585 ms
# 1000

# %%
while True:
    df = next(data_iter)
    
    df['tpep_pickup_datetime']=pd.to_datetime(df['tpep_pickup_datetime'])
    df['tpep_dropoff_datetime']=pd.to_datetime(df['tpep_dropoff_datetime'])
    df.to_sql(name='yellow_taxi_data', con = engine, if_exists='append')
    print('insert another chunk....')
# Out:
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# insert another chunk....
# ...
